# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
import requests

# %% [markdown]
# #### To connect to the URL and fetch the HTML content following things are required:
#
# 1. Define a get_data function which will input the page numbers as an argument,
# 2. Define a user-agent which will help in bypassing the detection as a scraper,
# 3. Specify the URL to requests.get and pass the user-agent header as an argument,
# 4. Extract the content from requests.get,
# 5. Scrape the specified page and assign it to soup variable,

# %% [markdown]
# ## 1. Extracting Data from the web https://www.aallyandsons.com/grocery/

# %%
# Getting request & Response
page = requests.get("https://www.aallyandsons.com/grocery/")
page
# Out:
# <Response [200]>

# %%
# Getting page content
soap1 = bs(page.content, 'html.parser')
soap1
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en">
# <head>
# <title>Grocery - Page 1 - A. Ally &amp; Sons</title>
# <link crossorigin="" href="https://cdn11.bigcommerce.com/s-mivyx18b6b" rel="dns-prefetch preconnect"/><link crossorigin="" href="https://fonts.googleapis.com" rel="dns-prefetch preconnect"/><link crossorigin="" href="https://fonts.gstatic.com" rel="dns-prefetch preconnect"/>
# <meta content="electronic" name="keywords"/><link href="https://www.aallyandsons.com/grocery/" rel="canonical"><link href="https://www.aallyandsons.com/amp/grocery/" rel="amphtml">
# <link href="https://www.aallyandsons.com/grocery/?sort=newest&amp;page=2" rel="next"/>
# <link href="https://cdn11.bigcommerce.com/s-mivyx18b6b/product_images/logo%20on%20website%20tab%202.png?t=1576524409" rel="shortcut icon"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <script>
# ...

# %%
# Targetting specific class 
soap1 = soap1.find('ul',class_='productGrid')

# %%
# Getting all Gerocery Product title
GroceryProduct = [text.get_text().replace('\n', "") for text in soap1.find_all(class_='card-title')]
GroceryProduct
# Out:
# ['REX IODIZED SALT 26oz 737g',
#  'POP TOYS ALBERTS ALL NEW TOYS 4TH SERIES  ARTIFICIALLY FLAVORED 0.88oz 25g SOLD EACH',
#  'NUTELLA FERRERO HAZELNUT SPREAD WITH COCOA 7.7oz 220g',
#  'KIT KAT SHARE MINIATURES 10.1oz 286g',
#  'BRAGG ORGANIC RAW UNFILTERED APPLE CIDER VINEGAR 16oz 473ml',
#  'LEE KUM KEE PANDA BRAND SWEET & SPICY GRILLING & DIPPING SAUCE 15oz 425g',
#  "LIBBY'S CREAM STYLE CORN 14.75oz 418g",
#  "HERSHEY'S KISSES MILK CHOCOLATE 1.55oz 43g",
#  'LEE KUM KEE PANDA BRAND LEMON PEPPER GRILLING & DIPPING SAUCE 15oz 425g',
#  'LEE KUM KEE HOISIN SAUCE 20oz (1lb 4oz) 567g',
#  'LEE KUM KEE PANDA BRAND OYSTER FLAVORED SAUCE 9oz 255g',
#  'LEE KUM KEE PANDA BRAND OYSTER FLAVORED SAUCE 18oz (1lb 2oz) 510g',
#  'LEE KUM KEE SWEET SOY SAUCE 14oz 410ml',
#  'LEE KUM KEE THAI STYLE SWEET CHILI SAUCE 18oz (1lb 2oz) 510g',
#  'LEE KUM KEE PEANUT FLAVORED SAUCE  8oz 226g',
#  'LEE KUM KEE CHILI GARLIC SAUCE 8oz 226g',
#  'LEE KUM KEE MINCED GARLIC 7.5oz 213g',
# ...

# %%
len(product)
# Out:
# 100

# %%
# Getting price of product in the list
BrandName = [text.get_text().replace('$', "") for text in soap1.find_all('p',class_="card-text card-text--brand")]
BrandName
# Out:
# ['Rex',
#  'ALBERTS',
#  'FERRERO',
#  'KIT KAT',
#  'Bragg',
#  'Lee Kum Kee',
#  "Libby's",
#  "Hershey's",
#  'Lee Kum Kee',
#  'Lee Kum Kee',
#  'Lee Kum Kee',
#  'Lee Kum Kee',
#  'Lee Kum Kee',
#  'Lee Kum Kee',
#  'Lee Kum Kee',
#  'Lee Kum Kee',
#  'Lee Kum Kee',
#  'Lee Kum Kee',
#  'Lee Kum Kee',
#  'Lee Kum Kee',
#  "Libby's",
#  "Hershey's",
#  "Hershey's",
#  'Lee Kum Kee',
#  "Libby's",
#  'Snickers',
#  'Snickers',
#  "Hershey's",
#  'Lee Kum Kee',
#  "Hershey's",
#  'Pepperidge Farm',
#  'Pepperidge Farm',
#  'Pepperidge Farm',
#  'Pepperidge Farm',
#  'Pepperidge Farm',
#  'Pepperidge Farm',
#  'Pepperidge Farm',
#  'Pepperidge Farm',
#  'Pepperidge Farm',
#  'Pepperidge Farm',
#  'Pepperidge Farm',
#  'Wonderful',
#  'Wonderful',
#  'Lee Kum Kee',
#  'Imperial Nuts',
#  'Ortega',
#  'Roland (Foods)',
#  'Imperial Nuts',
#  'Mrs Dash',
#  'Mrs Dash',
#  'Imperial Nuts',
#  'Imperial Nuts',
#  'Imperial Nuts',
#  'Imperial Nuts',
#  'Imperial Nuts',
# ...

# %%
# Converting data into pandas data frame
df = pd.DataFrame({'Product Title':GroceryProduct, 'Brand Name':BrandName})
df
# Out:
#                                         Product Title      Brand Name
# 0                          REX IODIZED SALT 26oz 737g             Rex
# 1   POP TOYS ALBERTS ALL NEW TOYS 4TH SERIES  ARTI...         ALBERTS
# 2   NUTELLA FERRERO HAZELNUT SPREAD WITH COCOA 7.7...         FERRERO
# 3                KIT KAT SHARE MINIATURES 10.1oz 286g         KIT KAT
# 4   BRAGG ORGANIC RAW UNFILTERED APPLE CIDER VINEG...           Bragg
# ..                                                ...             ...
# 95        LEE KUM KEE BROWN BRAISING SAUCE 14oz 410ml     Lee Kum Kee
# 96        CREAM OF WHEAT INSTANT CINNABON 12.3oz 350g  Cream Of Wheat
# 97               HY-TOP BROWNIE MIX FUDGE 18.3oz 519g          HY-TOP
# 98    CREAM OF WHEAT INSTANT VARIETY PACK 11.4oz 322g  Cream Of Wheat
# 99           LIBBY'S CLASSIC MAC & CHEESE 6.25oz 177g         Libby's
#
# [100 rows x 2 columns]

# %%
# Saving data to csv file
df.to_csv('aallyandsonsGroceryProduct.csv', index = False, encoding='utf-8')

# %%
# Reading Csv Data
data = pd.read_csv('aallyandsonsGroceryProduct.csv')
data
# Out:
#                                         Product Title      Brand Name
# 0                          REX IODIZED SALT 26oz 737g             Rex
# 1   POP TOYS ALBERTS ALL NEW TOYS 4TH SERIES  ARTI...         ALBERTS
# 2   NUTELLA FERRERO HAZELNUT SPREAD WITH COCOA 7.7...         FERRERO
# 3                KIT KAT SHARE MINIATURES 10.1oz 286g         KIT KAT
# 4   BRAGG ORGANIC RAW UNFILTERED APPLE CIDER VINEG...           Bragg
# ..                                                ...             ...
# 95        LEE KUM KEE BROWN BRAISING SAUCE 14oz 410ml     Lee Kum Kee
# 96        CREAM OF WHEAT INSTANT CINNABON 12.3oz 350g  Cream Of Wheat
# 97               HY-TOP BROWNIE MIX FUDGE 18.3oz 519g          HY-TOP
# 98    CREAM OF WHEAT INSTANT VARIETY PACK 11.4oz 322g  Cream Of Wheat
# 99           LIBBY'S CLASSIC MAC & CHEESE 6.25oz 177g         Libby's
#
# [100 rows x 2 columns]

# %% [markdown]
# # Using Selenium to srape data

# %%
from selenium import webdriver
import time

# %%
driver = webdriver.Chrome(executable_path='F:/Saylani.ai/Data Science/PracticalWork/WebScrapping/chromedriver_win32(2)/chromedriver.exe')

# %%
# Getting url
driver.get("https://www.eurasiaonline.ie/store/Above-5-Kg-c48470739")
